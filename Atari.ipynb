# %% [markdown]
# <a href="https://colab.research.google.com/github/paola-amigo/INM707-DRL/blob/main/Atari.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
import ray
from ray import tune
from ray.rllib.algorithms.dqn.dqn import DQNConfig
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
plt.plot(rewards)
plt.xlabel('Training Iteration')
plt.ylabel('Mean Episode Reward')
plt.title('DQN Training Results on Cart Pole')
plt.show()

# %%
from ray.rllib.algorithms.dqn.dqn import DQNConfig
from ray.tune.logger import pretty_print

algo = (
    DQNConfig()
    .rollouts(num_rollout_workers=1)
    .resources(num_gpus=0)
    .environment(env="CartPole-v1")
    .build()
)
rewards = []
for i in range(10):
    result = algo.train()
    print(pretty_print(result))
    rewards.append(result["episode_reward_mean"])

    if i % 5 == 0:
        checkpoint_dir = algo.save()
        print(f"Checkpoint saved in directory {checkpoint_dir}")

plt.plot(rewards)
plt.xlabel('Training Iteration')
plt.ylabel('Mean Episode Reward')
plt.title('DQN Training Results on Cart Pole')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (pid=81984) /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
# (pid=81984)   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# (pid=81984) /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# (pid=81984) Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# ...
